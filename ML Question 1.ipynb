# %% [markdown]
# # ML question 1
#
#
#
#
# INTERMEDIATE QUESTIONS :
# Q-1. Imagine you have a dataset where you have different Instagram features
# like u sername , Caption , Hashtag , Followers , Time_Since_posted , and likes , now your task is
# to predict the number of likes and Time Since posted and the rest of the features are
# your input features. Now you have to build a model which can predict the
# number of likes and Time Since posted.
# Dataset This is the Dataset You can use this dataset for this question.

# %%
import pandas as pd
import numpy as np

# %%
file_path = r'C:\Users\nikit\Downloads\archive (6)\instagram_reach.csv'
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Unnamed: 0  S.No              USERNAME  \
# 0           0     1         mikequindazzi
# 1           1     2       drgorillapaints
# 2           2     3    aitrading_official
# 3           3     4  opensourcedworkplace
# 4           4     5           crea.vision
#
#                                              Caption  Followers  \
# 0  Who are #DataScientist and what do they do? >>...       1600
# 1  We all know where it’s going. We just have to ...        880
# 2  Alexander Barinov: 4 years as CFO in multinati...        255
# 3                                               sfad        340
# 4  Ever missed a call while your phone was chargi...        304
#
#                                             Hashtags Time since posted  Likes
# 0  #MachineLearning #AI #DataAnalytics #DataScien...          11 hours    139
# 1   #deck .#mac #macintosh#sayhello #apple #steve...           2 hours     23
# 2  #whoiswho #aitrading #ai #aitradingteam#instat...           2 hours     25
# ...

# %%
df.shape
# Out:
# (100, 8)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'S.No', 'USERNAME', 'Caption', 'Followers', 'Hashtags',
#        'Time since posted', 'Likes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         100 non-null    int64
#  1   S.No               100 non-null    int64
#  2   USERNAME           100 non-null    object
#  3   Caption            94 non-null     object
#  4   Followers          100 non-null    int64
#  5   Hashtags           100 non-null    object
#  6   Time since posted  100 non-null    object
#  7   Likes              100 non-null    int64
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
missing_values = df.isnull().sum()

print(missing_values)
# Out:
# Unnamed: 0           0
# S.No                 0
# USERNAME             0
# Caption              6
# Followers            0
# Hashtags             0
# Time since posted    0
# Likes                0
# dtype: int64

# %%
#handling missing value
df['Caption'].fillna('No caption available', inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# S.No                 0
# USERNAME             0
# Caption              0
# Followers            0
# Hashtags             0
# Time since posted    0
# Likes                0
# dtype: int64

# %%
# Remove unnecessary columns
df= df.drop(['Unnamed: 0', 'S.No'], axis=1)

# %%
df.columns
# Out:
# Index(['USERNAME', 'Caption', 'Followers', 'Hashtags', 'Time since posted',
#        'Likes'],
#       dtype='object')

# %%
df.head()
# Out:
#                USERNAME                                            Caption  \
# 0         mikequindazzi  Who are #DataScientist and what do they do? >>...
# 1       drgorillapaints  We all know where it’s going. We just have to ...
# 2    aitrading_official  Alexander Barinov: 4 years as CFO in multinati...
# 3  opensourcedworkplace                                               sfad
# 4           crea.vision  Ever missed a call while your phone was chargi...
#
#    Followers                                           Hashtags  \
# 0       1600  #MachineLearning #AI #DataAnalytics #DataScien...
# 1        880   #deck .#mac #macintosh#sayhello #apple #steve...
# 2        255  #whoiswho #aitrading #ai #aitradingteam#instat...
# 3        340  #iot #cre#workplace #CDO #bigdata #technology#...
# 4        304  #instamachinelearning #instabigdata#instamarke...
#
#   Time since posted  Likes
# 0          11 hours    139
# 1           2 hours     23
# 2           2 hours     25
# ...

# %% [markdown]
# # Using EDA and Analysing Instagram Reach

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Histogram of numerical variables
df.hist(figsize=(10, 8))
plt.show()

# %%
# Box plot of numerical variables
sns.boxplot(data=df[['Followers', 'Likes']], orient='h')
plt.show()

# %%
# Bar plot of categorical variables
sns.countplot(data=df, x='Hashtags')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\nikit\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 127470 (\N{REGIONAL INDICATOR SYMBOL LETTER I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\nikit\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 127481 (\N{REGIONAL INDICATOR SYMBOL LETTER T}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Scatter plot of numerical variables
sns.scatterplot(data=df, x='Followers', y='Likes')
plt.show()

# %%
# Correlation matrix
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()
# Out:
# C:\Users\nikit\AppData\Local\Temp\ipykernel_22540\3170949178.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='coolwarm')

# %%
## Distribution of Impressions From Followers

plt.figure(figsize=(10, 8))
plt.style.use('fivethirtyeight')
plt.title("Distribution of Impressions From Followers")
sns.distplot(df['Followers'])
plt.show()
# Out:
# C:\Users\nikit\AppData\Local\Temp\ipykernel_22540\150198960.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Followers'])

# %%
## Distribution of Impressions From Likes

plt.figure(figsize=(10, 8))
plt.title("Distribution of Impressions From Likes")
sns.distplot(df['Likes'])
plt.show()
# Out:
# C:\Users\nikit\AppData\Local\Temp\ipykernel_22540\51960468.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Likes'])

# %%
## Relation between Likes and Followers
import plotly.express as px

followers_sum = df["Followers"].sum()
likes_sum = df["Likes"].sum()

labels = ['Followers', 'Likes']
values = [followers_sum, likes_sum]

fig = px.pie(names=labels, values=values, title='Relation between Likes and Followers', hole=0.5)
fig.show()
# Out:
# <div>                            <div id="f954598d-3437-43e5-907d-977d6c451b0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f954598d-3437-43e5-907d-977d6c451b0e")) {                    Plotly.newPlot(                        "f954598d-3437-43e5-907d-977d6c451b0e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["Followers","Likes"],"legendgroup":"","name":"","showlegend":true,"values":[96196,4648],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.33333
# ...

# %%
# !pip install wordcloud

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import warnings
warnings.filterwarnings('ignore')

# %%
## Plotting Word-Cloud for Hashtag Related Data

text = " ".join(i for i in df.Hashtags)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.style.use('classic')
plt.figure( figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # Model building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df.columns
# Out:
# Index(['USERNAME', 'Caption', 'Followers', 'Hashtags', 'Time since posted',
#        'Likes'],
#       dtype='object')

# %%
X = df[['USERNAME', 'Caption', 'Followers', 'Hashtags']]  # Include all the input features you mentioned
y_likes = df['Likes']  # Target variable: number of likes
y_time_since_posted = df['Time since posted']  # Target variable: time since posted

# %%
#split the data in train and test
X_train, X_test, y_likes_train, y_likes_test, y_time_train, y_time_test = train_test_split(X, y_likes, y_time_since_posted, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import OneHotEncoder

# Create an instance of the OneHotEncoder
encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')

# Fit and transform the training data
X_train_encoded = encoder.fit_transform(X_train)

# Transform the test data
X_test_encoded = encoder.transform(X_test)

# %% [markdown]
# # Train model to predict number of  likes

# %%
# Train a model to predict the number of likes
likes_model = LinearRegression()
likes_model.fit(X_train_encoded, y_likes_train)
likes_predictions = likes_model.predict(X_test_encoded)
likes_mse = mean_squared_error(y_likes_test, likes_predictions)
print("Mean Squared Error (Likes):", likes_mse)
# Out:
# Mean Squared Error (Likes): 1703.6703250244252

# %% [markdown]
# # Train model to predict Time since posted

# %%
#Define a function to extract the numerical value from the time string:
def extract_numerical_value(time_string):
    numerical_value = re.findall(r'\d+', time_string)[0]
    return int(numerical_value)

# %%
import re

# %%
#Apply the extraction function to the training and test data for the "time since posted" variable:
y_time_since_posted_train = y_time_train.apply(extract_numerical_value)
y_time_since_posted_test =y_time_test.apply(extract_numerical_value)

# %%
#Train a linear regression model to predict the time since posted:
time_since_posted_model = LinearRegression()
time_since_posted_model.fit(X_train_encoded, y_time_since_posted_train)
# Out:
# LinearRegression()

# %%
#Make predictions
time_since_posted_predictions = time_since_posted_model.predict(X_test_encoded)

# %%
# Calculate MSE
time_since_posted_mse = mean_squared_error(y_time_since_posted_test, time_since_posted_predictions)
print("Mean Squared Error (Time Since Posted):", time_since_posted_mse)
# Out:
# Mean Squared Error (Time Since Posted): 12.789791994168565

# %%
import matplotlib.pyplot as plt

# Scatter plot for number of likes
plt.scatter(y_likes_test, likes_predictions)
plt.xlabel('Actual Likes')
plt.ylabel('Predicted Likes')
plt.title('Linear Regression - Number of Likes')
plt.show()

# Scatter plot for time since posted
plt.scatter(y_time_since_posted_test, time_since_posted_predictions)
plt.xlabel('Actual Time Since Posted')
plt.ylabel('Predicted Time Since Posted')
plt.title('Linear Regression - Time Since Posted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sort the actual and predicted values based on the actual values
sorted_indices = np.argsort(y_likes_test)
sorted_actual_likes = np.array(y_likes_test)[sorted_indices]
sorted_predicted_likes = np.array(likes_predictions)[sorted_indices]

# Line plot for number of likes
plt.plot(range(len(sorted_actual_likes)), sorted_actual_likes, label='Actual Likes')
plt.plot(range(len(sorted_predicted_likes)), sorted_predicted_likes, label='Predicted Likes')
plt.xlabel('Index')
plt.ylabel('Number of Likes')
plt.title('Linear Regression - Number of Likes')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sort the actual and predicted values based on the actual values
sorted_indices = np.argsort(y_time_since_posted_test)
sorted_actual_time = np.array(y_time_since_posted_test)[sorted_indices]
sorted_predicted_time = np.array(time_since_posted_predictions)[sorted_indices]

# Line plot for time since posted
plt.plot(range(len(sorted_actual_time)), sorted_actual_time, label='Actual Time')
plt.plot(range(len(sorted_predicted_time)), sorted_predicted_time, label='Predicted Time')
plt.xlabel('Index')
plt.ylabel('Time Since Posted')
plt.title('Linear Regression - Time Since Posted')
plt.legend()
plt.show()

# %% [markdown]
# Based on the analysis and model building, here is a potential conclusion:
#
# Dataset Overview: The dataset consists of Instagram features such as username, caption, hashtags, followers, time since posted, and likes.
#
# Model Performance: The models were built to predict the number of likes and time since posted. The Mean Squared Error (MSE) was used to evaluate the performance of the models.
#
# Likes Prediction: The linear regression model for predicting the number of likes achieved an MSE of 1703.67. This indicates that the model's predictions have an average squared difference of 1703.67 from the actual number of likes.
#
# Time Since Posted Prediction: The linear regression model for predicting the time since posted achieved an MSE of 12.79. This means that, on average, the predicted time since posted has a squared difference of 12.79 from the actual time since posted.
#
# Feature Importance: The model considered features like username, caption, followers, and hashtags to make predictions. However, it's important to note that the impact and importance of these features may vary depending on the specific dataset and context. Further analysis, feature engineering, or experimentation may be required to determine the most influential features for predicting likes and time since posted accurately.
#
# Recommendations: Based on the analysis, there are several potential areas for improvement or further exploration:
#
# Feature Engineering: Consider exploring additional features or transforming existing features to improve model performance. For example, extracting more meaningful information from the caption or engineering new features related to engagement rates or posting frequency.
#
# Model Selection: Besides linear regression, consider experimenting with other machine learning algorithms that may better capture the underlying patterns and relationships in the data. Algorithms such as decision trees, random forests, or gradient boosting may be worth exploring.
#
# Data Collection: Collecting more data, if feasible, may help improve the models' predictive power. Increasing the sample size can lead to better generalization and model performance.
#
# Limitations: It's important to acknowledge the limitations of the analysis. These may include potential biases in the data, assumptions made during preprocessing, or limitations of the linear regression model itself. It's crucial to consider these limitations when interpreting the results and making decisions based on the model's predictions.
#
# Overall, the models provide a starting point for predicting the number of likes and time since posted based on the available Instagram features. However, further refinement, experimentation, and consideration of additional factors are recommended to enhance the accuracy and usefulness of the models.
#
#
# # Gradient boosting

# %%
#to implement gradient boosting for predicting the number of likes:
# Out:
# Mean Squared Error (Likes - Gradient Boosting): 1691.6119148239832

# %%
# Train model to predict Time since posted
# Train model to predict Time since posted
time_since_posted_gb_model = GradientBoostingRegressor()
time_since_posted_gb_model.fit(X_train_encoded, y_time_since_posted_train)
time_since_posted_gb_predictions = time_since_posted_gb_model.predict(X_test_encoded)
time_since_posted_gb_mse = mean_squared_error(y_time_since_posted_test, time_since_posted_gb_predictions)
print("Mean Squared Error (Time Since Posted - Gradient Boosting):", time_since_posted_gb_mse)
# Out:
# Mean Squared Error (Time Since Posted - Gradient Boosting): 14.067841822653104

# %%
import matplotlib.pyplot as plt

# Scatter plot for number of likes
plt.scatter(y_likes_test, likes_gb_predictions)
plt.xlabel('Actual Likes')
plt.ylabel('Predicted Likes')
plt.title('Gradient Boosting - Number of Likes')
plt.show()

# Scatter plot for time since posted
plt.scatter(y_time_since_posted_test, time_since_posted_gb_predictions)
plt.xlabel('Actual Time Since Posted')
plt.ylabel('Predicted Time Since Posted')
plt.title('Gradient Boosting - Time Since Posted')
plt.show()

# %%
import matplotlib.pyplot as plt

# Line plot for number of likes
plt.plot(range(len(y_likes_test)), y_likes_test, label='Actual Likes')
plt.plot(range(len(likes_gb_predictions)), likes_gb_predictions, label='Predicted Likes')
plt.xlabel('Samples')
plt.ylabel('Number of Likes')
plt.title('Gradient Boosting - Number of Likes')
plt.legend()
plt.show()

# Line plot for time since posted
plt.plot(range(len(y_time_since_posted_test)), y_time_since_posted_test, label='Actual Time Since Posted')
plt.plot(range(len(time_since_posted_gb_predictions)), time_since_posted_gb_predictions, label='Predicted Time Since Posted')
plt.xlabel('Samples')
plt.ylabel('Time Since Posted')
plt.title('Gradient Boosting - Time Since Posted')
plt.legend()
plt.show()

# %% [markdown]
# # Comparative Analysis

# %%
import matplotlib.pyplot as plt
import numpy as np

# Linear Regression - Number of Likes
plt.plot(range(len(sorted_actual_likes)), sorted_actual_likes, label='Actual Likes')
plt.plot(range(len(sorted_predicted_likes)), sorted_predicted_likes, label='Linear Regression Predicted Likes')
plt.xlabel('Index')
plt.ylabel('Number of Likes')
plt.title('Linear Regression - Number of Likes')
plt.legend()
plt.show()

# Linear Regression - Time Since Posted
plt.plot(range(len(sorted_actual_time)), sorted_actual_time, label='Actual Time')
plt.plot(range(len(sorted_predicted_time)), sorted_predicted_time, label='Linear Regression Predicted Time')
plt.xlabel('Index')
plt.ylabel('Time Since Posted')
plt.title('Linear Regression - Time Since Posted')
plt.legend()
plt.show()

# Gradient Boosting - Number of Likes
plt.plot(range(len(y_likes_test)), y_likes_test, label='Actual Likes')
plt.plot(range(len(likes_gb_predictions)), likes_gb_predictions, label='Gradient Boosting Predicted Likes')
plt.xlabel('Samples')
plt.ylabel('Number of Likes')
plt.title('Gradient Boosting - Number of Likes')
plt.legend()
plt.show()

# Gradient Boosting - Time Since Posted
plt.plot(range(len(y_time_since_posted_test)), y_time_since_posted_test, label='Actual Time Since Posted')
plt.plot(range(len(time_since_posted_gb_predictions)), time_since_posted_gb_predictions, label='Gradient Boosting Predicted Time')
plt.xlabel('Samples')
plt.ylabel('Time Since Posted')
plt.title('Gradient Boosting - Time Since Posted')
plt.legend()
plt.show()

# %%
# Calculate MSE for Linear Regression
likes_mse_linear = mean_squared_error(y_likes_test, likes_predictions)
time_since_posted_mse_linear = mean_squared_error(y_time_since_posted_test, time_since_posted_predictions)

# Calculate MSE for Gradient Boosting
likes_mse_gb = mean_squared_error(y_likes_test, likes_gb_predictions)
time_since_posted_mse_gb = mean_squared_error(y_time_since_posted_test, time_since_posted_gb_predictions)

# Print MSE values
print("Mean Squared Error (Likes) - Linear Regression:", likes_mse_linear)
print("Mean Squared Error (Time Since Posted) - Linear Regression:", time_since_posted_mse_linear)
print("Mean Squared Error (Likes) - Gradient Boosting:", likes_mse_gb)
print("Mean Squared Error (Time Since Posted) - Gradient Boosting:", time_since_posted_mse_gb)
# Out:
# Mean Squared Error (Likes) - Linear Regression: 1703.6703250244252
# Mean Squared Error (Time Since Posted) - Linear Regression: 12.789791994168565
# Mean Squared Error (Likes) - Gradient Boosting: 1691.6119148239832
# Mean Squared Error (Time Since Posted) - Gradient Boosting: 14.067841822653104

# %% [markdown]
# **In terms of the MSE values, lower values indicate better predictive performance. Comparing the MSE values for each task, we can see that linear regression performs slightly better for predicting the number of likes, as it has a slightly lower MSE than gradient boosting.**
#
# **On the other hand, for predicting the time since posted, linear regression also has a lower MSE than gradient boosting, indicating better performance in this case as well.**
